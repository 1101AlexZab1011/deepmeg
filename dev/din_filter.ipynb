# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rand1 = lambda: np.random.random()
rand10 = lambda: np.random.random()*10
rand100 = lambda: np.random.random()*100

dt = .01

gl = rand10()
gca = rand10()
gk = rand10()
vl = 2*rand100() - 100
vca = 2*rand100() - 100
vk = 2*rand100() - 100
I = rand10()
C = rand100()
tn = rand10()
v1, v2, v3, v4 = 2*rand10() - 10, 2*rand10() - 10, 2*rand10() - 10, 2*rand10() - 10

v = rand10() - 5
N = rand10() - 5
y = list()

for i in range(10000):
    dn = (1/2*(1 + np.tanh((v - v3)/v4)) - N)/tn*dt
    dv = (I - gl*(v - vl) - gca*(v - vca) - gk*N*(v - vk))*dt/C
    N += dn
    v += dv
    y.append(v)

plt.plot(y)

# %%
# dx = 2*np.random.random(1000) - 1
a = 1

y, y1 = list(), list()

w0 = 1
w1 = 1
dt = 0.01
for i, x in enumerate(dx):
    w0 += 10*(x * w0)*dt
    y.append(w0)

plt.plot(y)
plt.plot(dx)
