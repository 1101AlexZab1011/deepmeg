# %%
import numpy as np
import mne
from mne.datasets import sample
import numpy as np

import mne
mne.set_log_level(verbose='CRITICAL')
from mne.datasets import multimodal
from mne import channels, evoked, create_info
import matplotlib.pyplot as plt

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import scipy.signal as sl
from typing import Optional
import scipy as sp
import sys
from nilearn import plotting
sys.path.insert(1, os.path.realpath(os.path.pardir))
from deepmeg.experimental.models import SPIRIT
from deepmeg.data.datasets import EpochsDataset, read_epochs_dataset
from torch.utils.data import DataLoader
from deepmeg.preprocessing.transforms import zscore
import torch
from collections import defaultdict
import torchmetrics
from deepmeg.training.callbacks import Callback, EarlyStopping, L2Reg, PrintingCallback
from deepmeg.experimental.interpreters import SPIRITInterpreter
import random
import torch.nn as nn
from deepmeg.models.interpretable import BaseModel


def plot_metrics(metrics: dict[str, np.ndarray]):
    plot_dict = defaultdict(dict)

    for metric, values in metrics.items():
        metric_data = metric.split('_')
        metric_name = '_'.join(metric_data[:-1])
        metric_kind = metric_data[-1]
        plot_dict[metric_name][metric_kind] = values

    for metric_name, kind_dict in plot_dict.items():
        legend = list()
        for metric_kind, kind in kind_dict.items():
            plt.plot(kind)
            legend.append(metric_kind)
        plt.title(metric_name)
        plt.legend(legend)
        plt.show()

def accuracy(predictions, targets):

    # Convert one-hot encoded labels to class indices
    targets = torch.argmax(targets, dim=1)

    # Compute predicted class indices
    _, predicted = torch.max(predictions, dim=1)

    # Compute accuracy
    correct = torch.sum(predicted == targets)
    total = targets.shape[0]
    accuracy = correct / total

    return accuracy

# %%
from mne.datasets import multimodal
fname_raw = os.path.join(multimodal.data_path(), 'multimodal_raw.fif')
info = mne.io.read_raw_fif(fname_raw).resample(600).pick_types(meg='grad').info

# %%
dataset = read_epochs_dataset('../data/multimodal.pt')
train, test = torch.utils.data.random_split(dataset, [.7, .3])
x, y = next(iter(DataLoader(test, len(test))))
y.shape
# Out:
# torch.Size([282, 8])

# %%
class LFCNN_original(BaseModel):

    def __init__(
        self,
        n_channels: int,
        n_times: int,
        n_latent: int,
        filter_size: int,
        pool_factor: int,
        n_outputs: int
    ):
        super().__init__()
        self.pool_factor = pool_factor
        self.n_latent = n_latent
        # self.unmixing_layer = nn.Conv1d(n_channels, n_latent, kernel_size=1, bias=True)
        self.unmixing_layer = nn.Linear(n_channels, n_latent, bias=True)
        self.temp_conv = nn.Conv1d(n_latent, n_latent, kernel_size=filter_size, bias=True, groups=n_latent, padding='same')
        self.max_pool = nn.MaxPool2d((1, pool_factor))
        self.relu = nn.ReLU()
        final_out_features = (n_times//pool_factor)*n_latent
        self.fc_layer = nn.Linear(final_out_features, n_outputs)


    def forward(self, x: torch.Tensor):
        x = self.unmixing_layer(x.permute(0, -1, 1))
        x = self.temp_conv(x.permute(0, -1, 1))
        x = self.relu(x)
        x = self.max_pool(x)
        x = torch.flatten(x, 1)
        return self.fc_layer(x)

X = torch.rand((1, 204, 301))

LFCNN_original(204, 301, 8, 50, 10, 8)(X)
# Out:
# /home/user/Projects/deepmeg/venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:309: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:1003.)
#   return F.conv1d(input, weight, bias, self.stride,
# tensor([[-0.2711,  0.2722,  0.0500, -0.1191, -0.2261, -0.0995, -0.0394,  0.2216]],
#        grad_fn=<AddmmBackward0>)

# %%
kwargs = dict(
    n_channels=x.shape[1],
    n_times=x.shape[-1],
    filter_size=50,
    n_latent=8,
    pool_factor=10,
    n_outputs=y.shape[-1]
)

# %%
LFCNN_original(
    **kwargs
)(x).shape
# Out:
# torch.Size([282, 8])

# %%
from deepmeg.models.interpretable import LFCNN, BaseModel
# model = TSNet(**lfcnn_kwargs)

model = LFCNN_original(
    **kwargs
)

optimizer = torch.optim.Adam
loss = torch.nn.BCEWithLogitsLoss()
# loss = torch.nn.CrossEntropyLoss()
# metric = torchmetrics.functional.classification.binary_accuracy
metric = accuracy

model.compile(
    optimizer,
    loss,
    metric,
    callbacks=[
        PrintingCallback(), # print ongoing training history
        EarlyStopping(patience=15, monitor='loss_val', restore_best_weights=True), # perform early stopping with restoring best weights
        L2Reg(
            [
                'unmixing_layer.weight',
                'temp_conv.weight',
            ], lambdas=.01
        ) # l2 regularization for weights of spatial- and temporal filtering layers
    ]
)

# %%
if hasattr(sys.stdout, 'file'):
    sys.stdout = sys.stdout.file

# %%
history = model.fit(train, n_epochs=150, batch_size=200, val_batch_size=60)
plot_metrics(history)
# Out:
# Epoch 0:  loss_train:  0.6920   |    accuracy_train:  0.1230   |    loss_val:  0.6227   |    accuracy_val:  0.1694
# Epoch 1:  loss_train:  0.5913   |    accuracy_train:  0.1326   |    loss_val:  0.5332   |    accuracy_val:  0.2131
# Epoch 2:  loss_train:  0.5075   |    accuracy_train:  0.1340   |    loss_val:  0.4640   |    accuracy_val:  0.1912
# Epoch 3:  loss_train:  0.4477   |    accuracy_train:  0.1372   |    loss_val:  0.4252   |    accuracy_val:  0.1805
# Epoch 4:  loss_train:  0.4200   |    accuracy_train:  0.1436   |    loss_val:  0.4184   |    accuracy_val:  0.1860
# Epoch 5:  loss_train:  0.4193   |    accuracy_train:  0.1463   |    loss_val:  0.4263   |    accuracy_val:  0.1808
# Epoch 6:  loss_train:  0.4248   |    accuracy_train:  0.1769   |    loss_val:  0.4283   |    accuracy_val:  0.2082
# Epoch 7:  loss_train:  0.4216   |    accuracy_train:  0.2045   |    loss_val:  0.4212   |    accuracy_val:  0.2305
# Epoch 8:  loss_train:  0.4113   |    accuracy_train:  0.2549   |    loss_val:  0.4119   |    accuracy_val:  0.2471
# Epoch 9:  loss_train:  0.4012   |    accuracy_train:  0.2924   |    loss_val:  0.4059   |    accuracy_val:  0.1989
# Epoch 10: loss_train:  0.3951   |    accuracy_train:  0.3325   |    loss_val:  0.4033   |    accuracy_val:  0.2156
# Epoch 11: loss_train:  0.3918   |    accuracy_train:  0.3691   |    loss_val:  0.4014   |    accuracy_val:  0.2156
# Epoch 12: loss_train:  0.3887   |    accuracy_train:  0.3808   |    loss_val:  0.3982   |    accuracy_val:  0.2267
# Epoch 13: loss_train:  0.3840   |    accuracy_train:  0.4068   |    loss_val:  0.3934   |    accuracy_val:  0.2323
# Epoch 14: loss_train:  0.3781   |    accuracy_train:  0.4228   |    loss_val:  0.3879   |    accuracy_val:  0.2434
# Epoch 15: loss_train:  0.3718   |    accuracy_train:  0.4476   |    loss_val:  0.3827   |    accuracy_val:  0.2434
# Epoch 16: loss_train:  0.3657   |    accuracy_train:  0.4574   |    loss_val:  0.3776   |    accuracy_val:  0.2815
# Epoch 17: loss_train:  0.3594   |    accuracy_train:  0.4875   |    loss_val:  0.3721   |    accuracy_val:  0.2982
# Epoch 18: loss_train:  0.3524   |    accuracy_train:  0.4977   |    loss_val:  0.3657   |    accuracy_val:  0.3312
# Epoch 19: loss_train:  0.3445   |    accuracy_train:  0.5127   |    loss_val:  0.3590   |    accuracy_val:  0.3475
# Epoch 20: loss_train:  0.3362   |    accuracy_train:  0.5402   |    loss_val:  0.3522   |    accuracy_val:  0.3697
# Epoch 21: loss_train:  0.3279   |    accuracy_train:  0.5583   |    loss_val:  0.3459   |    accuracy_val:  0.3805
# Epoch 22: loss_train:  0.3195   |    accuracy_train:  0.5939   |    loss_val:  0.3399   |    accuracy_val:  0.3964
# Epoch 23: loss_train:  0.3110   |    accuracy_train:  0.6347   |    loss_val:  0.3341   |    accuracy_val:  0.4131
# Epoch 24: loss_train:  0.3023   |    accuracy_train:  0.6667   |    loss_val:  0.3285   |    accuracy_val:  0.4575
# Epoch 25: loss_train:  0.2933   |    accuracy_train:  0.6762   |    loss_val:  0.3229   |    accuracy_val:  0.4735
# Epoch 26: loss_train:  0.2842   |    accuracy_train:  0.6944   |    loss_val:  0.3174   |    accuracy_val:  0.4790
# Epoch 27: loss_train:  0.2749   |    accuracy_train:  0.7160   |    loss_val:  0.3118   |    accuracy_val:  0.5124
# Epoch 28: loss_train:  0.2653   |    accuracy_train:  0.7373   |    loss_val:  0.3061   |    accuracy_val:  0.5398
# Epoch 29: loss_train:  0.2556   |    accuracy_train:  0.7375   |    loss_val:  0.3004   |    accuracy_val:  0.5672
# Epoch 30: loss_train:  0.2459   |    accuracy_train:  0.7570   |    loss_val:  0.2947   |    accuracy_val:  0.5891
# Epoch 31: loss_train:  0.2362   |    accuracy_train:  0.7702   |    loss_val:  0.2892   |    accuracy_val:  0.5891
# Epoch 32: loss_train:  0.2266   |    accuracy_train:  0.7881   |    loss_val:  0.2839   |    accuracy_val:  0.5998
# Epoch 33: loss_train:  0.2173   |    accuracy_train:  0.8093   |    loss_val:  0.2788   |    accuracy_val:  0.5998
# Epoch 34: loss_train:  0.2082   |    accuracy_train:  0.8303   |    loss_val:  0.2738   |    accuracy_val:  0.6109
# Epoch 35: loss_train:  0.1995   |    accuracy_train:  0.8467   |    loss_val:  0.2690   |    accuracy_val:  0.6269
# Epoch 36: loss_train:  0.1912   |    accuracy_train:  0.8546   |    loss_val:  0.2643   |    accuracy_val:  0.6380
# Epoch 37: loss_train:  0.1833   |    accuracy_train:  0.8692   |    loss_val:  0.2596   |    accuracy_val:  0.6547
# Epoch 38: loss_train:  0.1759   |    accuracy_train:  0.8759   |    loss_val:  0.2549   |    accuracy_val:  0.6869
# Epoch 39: loss_train:  0.1688   |    accuracy_train:  0.8909   |    loss_val:  0.2504   |    accuracy_val:  0.6925
# Epoch 40: loss_train:  0.1622   |    accuracy_train:  0.9009   |    loss_val:  0.2460   |    accuracy_val:  0.7032
# Epoch 41: loss_train:  0.1560   |    accuracy_train:  0.9107   |    loss_val:  0.2420   |    accuracy_val:  0.6980
# Epoch 42: loss_train:  0.1502   |    accuracy_train:  0.9173   |    loss_val:  0.2381   |    accuracy_val:  0.7088
# Epoch 43: loss_train:  0.1448   |    accuracy_train:  0.9190   |    loss_val:  0.2344   |    accuracy_val:  0.7306
# Epoch 44: loss_train:  0.1397   |    accuracy_train:  0.9307   |    loss_val:  0.2309   |    accuracy_val:  0.7525
# Epoch 45: loss_train:  0.1350   |    accuracy_train:  0.9371   |    loss_val:  0.2278   |    accuracy_val:  0.7581
# Epoch 46: loss_train:  0.1306   |    accuracy_train:  0.9488   |    loss_val:  0.2250   |    accuracy_val:  0.7525
# Epoch 47: loss_train:  0.1264   |    accuracy_train:  0.9538   |    loss_val:  0.2226   |    accuracy_val:  0.7581
# Epoch 48: loss_train:  0.1226   |    accuracy_train:  0.9554   |    loss_val:  0.2206   |    accuracy_val:  0.7581
# Epoch 49: loss_train:  0.1191   |    accuracy_train:  0.9554   |    loss_val:  0.2188   |    accuracy_val:  0.7636
# Epoch 50: loss_train:  0.1158   |    accuracy_train:  0.9571   |    loss_val:  0.2173   |    accuracy_val:  0.7799
# Epoch 51: loss_train:  0.1127   |    accuracy_train:  0.9669   |    loss_val:  0.2162   |    accuracy_val:  0.7907
# Epoch 52: loss_train:  0.1098   |    accuracy_train:  0.9752   |    loss_val:  0.2152   |    accuracy_val:  0.7907
# Epoch 53: loss_train:  0.1072   |    accuracy_train:  0.9752   |    loss_val:  0.2146   |    accuracy_val:  0.8014
# Epoch 54: loss_train:  0.1047   |    accuracy_train:  0.9769   |    loss_val:  0.2141   |    accuracy_val:  0.7959
# Epoch 55: loss_train:  0.1024   |    accuracy_train:  0.9786   |    loss_val:  0.2140   |    accuracy_val:  0.8014
# Epoch 56: loss_train:  0.1003   |    accuracy_train:  0.9786   |    loss_val:  0.2140   |    accuracy_val:  0.8014
# Epoch 57: loss_train:  0.0983   |    accuracy_train:  0.9786   |    loss_val:  0.2143   |    accuracy_val:  0.8070
# Epoch 58: loss_train:  0.0964   |    accuracy_train:  0.9802   |    loss_val:  0.2147   |    accuracy_val:  0.8070
# Epoch 59: loss_train:  0.0947   |    accuracy_train:  0.9819   |    loss_val:  0.2152   |    accuracy_val:  0.8070
# Epoch 60: loss_train:  0.0931   |    accuracy_train:  0.9819   |    loss_val:  0.2158   |    accuracy_val:  0.8070
# Epoch 61: loss_train:  0.0916   |    accuracy_train:  0.9836   |    loss_val:  0.2165   |    accuracy_val:  0.8014
# Epoch 62: loss_train:  0.0901   |    accuracy_train:  0.9852   |    loss_val:  0.2173   |    accuracy_val:  0.8014
# Epoch 63: loss_train:  0.0888   |    accuracy_train:  0.9917   |    loss_val:  0.2182   |    accuracy_val:  0.8014
# Epoch 64: loss_train:  0.0876   |    accuracy_train:  0.9933   |    loss_val:  0.2192   |    accuracy_val:  0.8070
# Epoch 65: loss_train:  0.0864   |    accuracy_train:  0.9950   |    loss_val:  0.2202   |    accuracy_val:  0.8070
# Epoch 66: loss_train:  0.0853   |    accuracy_train:  0.9967   |    loss_val:  0.2213   |    accuracy_val:  0.8070
# Epoch 67: loss_train:  0.0843   |    accuracy_train:  0.9967   |    loss_val:  0.2226   |    accuracy_val:  0.8070
# Epoch 68: loss_train:  0.0833   |    accuracy_train:  0.9983   |    loss_val:  0.2239   |    accuracy_val:  0.8070
# Epoch 69: loss_train:  0.0824   |    accuracy_train:  0.9983   |    loss_val:  0.2252   |    accuracy_val:  0.8070
# Epoch 70: loss_train:  0.0816   |    accuracy_train:  0.9983   |    loss_val:  0.2266   |    accuracy_val:  0.8070
# The training loop was completed at epoch 72 due to an interruption
#  47%|████▋     | 71/150 [00:37<00:41,  1.89it/s]

# %%
train_result = model.evaluate(train)
result = model.evaluate(test)

for measure, value in train_result.items():
    print(f'train_{measure}: {value}')

for measure, value in result.items():
    print(f'{measure}: {value}')
# Out:
# train_loss: 0.12772134623744272
# train_accuracy: 0.9384615421295166
# loss: 0.20405057885430075
# accuracy: 0.8214285752990029

# %%
class LFCNN(BaseModel):

    def __init__(
        self,
        n_channels: int,
        n_times: int,
        n_latent: int,
        filter_size: int,
        pool_factor: int,
        n_outputs: int
    ):
        super().__init__()
        self.pool_factor = pool_factor
        self.n_latent = n_latent
        self.unmixing_layer = nn.Linear(n_channels, n_latent, bias=True)
        self.temp_conv = nn.Conv1d(n_latent, n_latent, kernel_size=filter_size, bias=True, groups=n_latent, padding='same')
        final_out_features = (n_times//pool_factor)*n_latent if not n_times%pool_factor else (n_times//pool_factor + 1)*n_latent
        self.fc_layer = nn.Linear(final_out_features, n_outputs)


    def forward(self, x: torch.Tensor):
        x = self.unmixing_layer(x.permute(0, -1, 1))
        x = self.temp_conv(x.permute(0, -1, 1))
        x = x[:, :, ::self.pool_factor].contiguous()
        x = torch.flatten(x, 1)
        return self.fc_layer(x)

X = torch.rand((1, 204, 301))

LFCNN(204, 301, 8, 50, 10, 8)(X)
# Out:
# /home/user/Projects/deepmeg/venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:309: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:1003.)
#   return F.conv1d(input, weight, bias, self.stride,
# tensor([[ 0.0277,  0.0317, -0.0253, -0.0031,  0.1022, -0.1843, -0.1350, -0.2432]],
#        grad_fn=<AddmmBackward0>)

# %%
model = LFCNN(
    **kwargs
)

optimizer = torch.optim.Adam
loss = torch.nn.BCEWithLogitsLoss()
metric = accuracy

model.compile(
    optimizer,
    loss,
    metric,
    callbacks=[
        PrintingCallback(), # print ongoing training history
        EarlyStopping(patience=15, monitor='loss_val', restore_best_weights=True), # perform early stopping with restoring best weights
        L2Reg(
            [
                'unmixing_layer.weight',
                'temp_conv.weight',
            ], lambdas=.01
        ) # l2 regularization for weights of spatial- and temporal filtering layers
    ]
)

# %%
history = model.fit(train, n_epochs=150, batch_size=200, val_batch_size=60)
plot_metrics(history)
# Out:
# Epoch 0:  loss_train:  0.7188   |    accuracy_train:  0.1348   |    loss_val:  0.6984   |    accuracy_val:  0.1645
# Epoch 1:  loss_train:  0.6901   |    accuracy_train:  0.1740   |    loss_val:  0.6713   |    accuracy_val:  0.1812
# Epoch 2:  loss_train:  0.6581   |    accuracy_train:  0.1935   |    loss_val:  0.6398   |    accuracy_val:  0.1978
# Epoch 3:  loss_train:  0.6206   |    accuracy_train:  0.2408   |    loss_val:  0.6040   |    accuracy_val:  0.2367
# Epoch 4:  loss_train:  0.5782   |    accuracy_train:  0.2859   |    loss_val:  0.5661   |    accuracy_val:  0.2860
# Epoch 5:  loss_train:  0.5346   |    accuracy_train:  0.3296   |    loss_val:  0.5309   |    accuracy_val:  0.3082
# Epoch 6:  loss_train:  0.4956   |    accuracy_train:  0.3415   |    loss_val:  0.5029   |    accuracy_val:  0.3357
# Epoch 7:  loss_train:  0.4643   |    accuracy_train:  0.3821   |    loss_val:  0.4807   |    accuracy_val:  0.3516
# Epoch 8:  loss_train:  0.4380   |    accuracy_train:  0.4129   |    loss_val:  0.4605   |    accuracy_val:  0.3297
# Epoch 9:  loss_train:  0.4129   |    accuracy_train:  0.4420   |    loss_val:  0.4398   |    accuracy_val:  0.3627
# Epoch 10: loss_train:  0.3886   |    accuracy_train:  0.4778   |    loss_val:  0.4202   |    accuracy_val:  0.3842
# Epoch 11: loss_train:  0.3673   |    accuracy_train:  0.5036   |    loss_val:  0.4052   |    accuracy_val:  0.3898
# Epoch 12: loss_train:  0.3504   |    accuracy_train:  0.5429   |    loss_val:  0.3947   |    accuracy_val:  0.4224
# Epoch 13: loss_train:  0.3362   |    accuracy_train:  0.5754   |    loss_val:  0.3845   |    accuracy_val:  0.4276
# Epoch 14: loss_train:  0.3223   |    accuracy_train:  0.6031   |    loss_val:  0.3731   |    accuracy_val:  0.4387
# Epoch 15: loss_train:  0.3088   |    accuracy_train:  0.6339   |    loss_val:  0.3622   |    accuracy_val:  0.4498
# Epoch 16: loss_train:  0.2956   |    accuracy_train:  0.6649   |    loss_val:  0.3516   |    accuracy_val:  0.4720
# Epoch 17: loss_train:  0.2826   |    accuracy_train:  0.7005   |    loss_val:  0.3402   |    accuracy_val:  0.4943
# Epoch 18: loss_train:  0.2696   |    accuracy_train:  0.7398   |    loss_val:  0.3293   |    accuracy_val:  0.5217
# Epoch 19: loss_train:  0.2568   |    accuracy_train:  0.7637   |    loss_val:  0.3200   |    accuracy_val:  0.5654
# Epoch 20: loss_train:  0.2444   |    accuracy_train:  0.7787   |    loss_val:  0.3116   |    accuracy_val:  0.6373
# Epoch 21: loss_train:  0.2323   |    accuracy_train:  0.7983   |    loss_val:  0.3038   |    accuracy_val:  0.6591
# Epoch 22: loss_train:  0.2207   |    accuracy_train:  0.8131   |    loss_val:  0.2967   |    accuracy_val:  0.6591
# Epoch 23: loss_train:  0.2094   |    accuracy_train:  0.8281   |    loss_val:  0.2902   |    accuracy_val:  0.6758
# Epoch 24: loss_train:  0.1986   |    accuracy_train:  0.8441   |    loss_val:  0.2843   |    accuracy_val:  0.6814
# Epoch 25: loss_train:  0.1884   |    accuracy_train:  0.8605   |    loss_val:  0.2791   |    accuracy_val:  0.6977
# Epoch 26: loss_train:  0.1788   |    accuracy_train:  0.8657   |    loss_val:  0.2744   |    accuracy_val:  0.7084
# Epoch 27: loss_train:  0.1697   |    accuracy_train:  0.8838   |    loss_val:  0.2700   |    accuracy_val:  0.7358
# Epoch 28: loss_train:  0.1613   |    accuracy_train:  0.8967   |    loss_val:  0.2659   |    accuracy_val:  0.7303
# Epoch 29: loss_train:  0.1536   |    accuracy_train:  0.9065   |    loss_val:  0.2622   |    accuracy_val:  0.7470
# Epoch 30: loss_train:  0.1464   |    accuracy_train:  0.9130   |    loss_val:  0.2586   |    accuracy_val:  0.7581
# Epoch 31: loss_train:  0.1399   |    accuracy_train:  0.9261   |    loss_val:  0.2554   |    accuracy_val:  0.7692
# Epoch 32: loss_train:  0.1340   |    accuracy_train:  0.9392   |    loss_val:  0.2526   |    accuracy_val:  0.7858
# Epoch 33: loss_train:  0.1285   |    accuracy_train:  0.9392   |    loss_val:  0.2502   |    accuracy_val:  0.7858
# Epoch 34: loss_train:  0.1235   |    accuracy_train:  0.9442   |    loss_val:  0.2482   |    accuracy_val:  0.7914
# Epoch 35: loss_train:  0.1189   |    accuracy_train:  0.9554   |    loss_val:  0.2464   |    accuracy_val:  0.7970
# Epoch 36: loss_train:  0.1146   |    accuracy_train:  0.9569   |    loss_val:  0.2449   |    accuracy_val:  0.7970
# Epoch 37: loss_train:  0.1107   |    accuracy_train:  0.9569   |    loss_val:  0.2436   |    accuracy_val:  0.8081
# Epoch 38: loss_train:  0.1070   |    accuracy_train:  0.9586   |    loss_val:  0.2427   |    accuracy_val:  0.8136
# Epoch 39: loss_train:  0.1036   |    accuracy_train:  0.9602   |    loss_val:  0.2420   |    accuracy_val:  0.8244
# Epoch 40: loss_train:  0.1005   |    accuracy_train:  0.9667   |    loss_val:  0.2415   |    accuracy_val:  0.8244
# Epoch 41: loss_train:  0.0976   |    accuracy_train:  0.9683   |    loss_val:  0.2412   |    accuracy_val:  0.8244
# Epoch 42: loss_train:  0.0949   |    accuracy_train:  0.9750   |    loss_val:  0.2410   |    accuracy_val:  0.8299
# Epoch 43: loss_train:  0.0924   |    accuracy_train:  0.9783   |    loss_val:  0.2412   |    accuracy_val:  0.8410
# Epoch 44: loss_train:  0.0900   |    accuracy_train:  0.9833   |    loss_val:  0.2415   |    accuracy_val:  0.8410
# Epoch 45: loss_train:  0.0878   |    accuracy_train:  0.9867   |    loss_val:  0.2419   |    accuracy_val:  0.8410
# Epoch 46: loss_train:  0.0858   |    accuracy_train:  0.9883   |    loss_val:  0.2424   |    accuracy_val:  0.8410
# Epoch 47: loss_train:  0.0839   |    accuracy_train:  0.9917   |    loss_val:  0.2430   |    accuracy_val:  0.8410
# Epoch 48: loss_train:  0.0822   |    accuracy_train:  0.9933   |    loss_val:  0.2437   |    accuracy_val:  0.8466
# Epoch 49: loss_train:  0.0805   |    accuracy_train:  0.9933   |    loss_val:  0.2444   |    accuracy_val:  0.8466
# Epoch 50: loss_train:  0.0790   |    accuracy_train:  0.9950   |    loss_val:  0.2452   |    accuracy_val:  0.8466
# Epoch 51: loss_train:  0.0776   |    accuracy_train:  0.9967   |    loss_val:  0.2461   |    accuracy_val:  0.8466
# Epoch 52: loss_train:  0.0763   |    accuracy_train:  0.9967   |    loss_val:  0.2471   |    accuracy_val:  0.8466
# Epoch 53: loss_train:  0.0751   |    accuracy_train:  0.9967   |    loss_val:  0.2481   |    accuracy_val:  0.8522
# Epoch 54: loss_train:  0.0740   |    accuracy_train:  0.9967   |    loss_val:  0.2491   |    accuracy_val:  0.8522
# Epoch 55: loss_train:  0.0729   |    accuracy_train:  0.9983   |    loss_val:  0.2502   |    accuracy_val:  0.8522
# Epoch 56: loss_train:  0.0720   |    accuracy_train:  0.9983   |    loss_val:  0.2514   |    accuracy_val:  0.8522
# Epoch 57: loss_train:  0.0711   |    accuracy_train:  0.9983   |    loss_val:  0.2526   |    accuracy_val:  0.8522
# The training loop was completed at epoch 59 due to an interruption
#  39%|███▊      | 58/150 [00:38<01:00,  1.51it/s]

# %%
train_result = model.evaluate(train)
result = model.evaluate(test)

for measure, value in train_result.items():
    print(f'train_{measure}: {value}')

for measure, value in result.items():
    print(f'{measure}: {value}')
# Out:
# train_loss: 0.13186277990991419
# train_accuracy: 0.9368881149725481
# loss: 0.22104598581790924
# accuracy: 0.8733766241507097
