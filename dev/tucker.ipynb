# %%
import os
import warnings
warnings.filterwarnings(action='once')
from nilearn import datasets
from nilearn.input_data import NiftiMasker
import numpy as np
# cognitive annotations
import pandas as pd
import os
import sys
sys.path.insert(1, os.path.realpath(os.path.pardir))
import numpy as np
import matplotlib.pyplot as plt
from typing import Callable, Sequence, Any
from deepmeg.preprocessing.transforms import one_hot_encoder, zscore
from deepmeg.data.datasets import EpochsDataset
from deepmeg.models import BaseModel
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torchmetrics
from deepmeg.training.callbacks import EarlyStopping, PrintingCallback, L2Reg
from deepmeg.utils.viz import plot_metrics
from functools import partial
from deepmeg.utils.convtools import compute_output_shape, conviter
import torch.nn.init as init
import math
from deepmeg.preprocessing.transforms import one_hot_encoder, one_hot_decoder
import nibabel as nb
import nilearn.plotting as nplt


def accuracy(predictions, targets):
    """
    Computes the accuracy metric for multiclass tasks with one-hot encoded labels.

    Args:
    - predictions: A PyTorch tensor of shape (batch_size, num_classes) representing the model's predictions.
    - targets: A PyTorch tensor of shape (batch_size, num_classes) representing the true labels in one-hot encoded format.

    Returns:
    - accuracy: A float value representing the accuracy metric.
    """

    # Convert one-hot encoded labels to class indices
    targets = torch.argmax(targets, dim=1)

    # Compute predicted class indices
    _, predicted = torch.max(predictions, dim=1)

    # Compute accuracy
    correct = torch.sum(predicted == targets)
    total = targets.shape[0]
    accuracy = correct / total

    return accuracy


def plot_2d_projections(matrix: np.ndarray, cmap=None) -> plt.Figure:
    """
    Plot the mean projections of a 3D matrix along the X, Y, and Z axes.

    Args:
        matrix (np.ndarray): A 3D matrix to plot.

    Returns:
        plt.Figure: A matplotlib Figure object containing the 2D projections along the X, Y, and Z axes.
    """
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    ax1.imshow(np.flip(matrix.mean(axis=0).T, 0), cmap=cmap)
    ax2.imshow(np.flip(matrix.mean(axis=1).T, 0), cmap=cmap)
    ax3.imshow(np.flip(matrix.mean(axis=2).T, 0), cmap=cmap)
    return fig
# Out:
# /home/user/Projects/deepmeg/venv/lib/python3.11/site-packages/nilearn/input_data/__init__.py:23: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
def mode_n_product(x, m, mode):
    x = np.asarray(x)
    m = np.asarray(m)
    if mode < 0:
        raise ValueError('`mode` must be a positive interger')
    if x.ndim < mode:
        raise ValueError('Invalid shape of X for mode = {}: {}'.format(mode, x.shape))
    if m.ndim != 2:
        raise ValueError('Invalid shape of M: {}'.format(m.shape))
    return np.swapaxes(np.swapaxes(x, mode, -1).dot(m.T), mode, -1)


A = np.reshape(np.arange(12) + 1, (2, 2, 3))
B = np.reshape(np.arange(6) + 1, (3, 2))

c = mode_n_product(A, B, 1)

# %%
c[0, :, :]
# Out:
# tensor([[ 9, 12, 15],
#         [19, 26, 33],
#         [29, 40, 51]])

# %%
B@A[0, :, :]
# Out:
# array([[ 9, 12, 15],
#        [19, 26, 33],
#        [29, 40, 51]])

# %%
A.shape, B.shape, c.shape
# Out:
# ((2, 2, 3), (3, 2), torch.Size([2, 3, 3]))

# %%
d = np.tensordot(B, A, axes=([1],[1]))

# %%
c.shape
# Out:
# torch.Size([2, 3, 3])

# %%
c[0, :, :]
# Out:
# tensor([[ 9, 12, 15],
#         [19, 26, 33],
#         [29, 40, 51]])

# %%
x, y, z = 100, 100, 100
m, n, p = 10, 10, 10

print(
    x*n + y*m + z*p + m*n*p,
    x*m*p + n*y*p + n*m*z,
    (x*m*p + n*y*p + n*m*z) / (x*n + y*m + z*p + m*n*p)
)
B1, B2, B3 = np.random.random((x, m)) - .5, np.random.random((y, n)) - .5, np.random.random((z, p)) - .5
g = np.random.random((m, n, p)) - .5
# Out:
# 4000 30000 7.5

# %%
B1.shape, B2.shape, B3.shape, g.shape
# Out:
# ((100, 10), (100, 10), (100, 10), (10, 10, 10))

# %%
# Im1 = np.tensordot(B1, g, axes=([1],[1]))
Im1 = mode_n_product(g, B1, 0)
Im2 = mode_n_product(Im1, B2, 1)
Im3 = mode_n_product(Im2, B3, 2)
# Im2 = np.tensordot(B2, Im1, axes=([1],[1]))
Im3.shape
# Out:
# torch.Size([100, 100, 100])

# %%
np.expand_dims(B.copy().flatten(), 1).T @ np.expand_dims(B.copy().flatten(), 1)
# Out:
# array([[91]])

# %%
(B*B).sum()
# Out:
# 91

# %%
def mode_n_product(x, m, axis):
    x = torch.as_tensor(x)
    m = torch.as_tensor(m)
    if axis < 0:
        raise ValueError('`mode` must be a positive integer')
    if x.ndim < axis:
        raise ValueError('Invalid shape of X for mode = {}: {}'.format(axis, x.shape))
    if m.ndim != 2:
        raise ValueError('Invalid shape of M: {}'.format(m.shape))

    # Move the mode axis to the last position
    x = x.permute(*list(range(axis)) + list(range(axis + 1, x.ndim)) + [axis])

    # Perform matrix multiplication
    result = torch.matmul(x, m.T)

    # Move the mode axis back to its original position
    result = result.permute(*list(range(axis)) + [result.ndim - 1] + list(range(axis, result.ndim - 1)))

    return result


class LinearTucker(nn.Module):
    def __init__(self, input_dim, kernel_size):

        super().__init__()
        self.input_dim = input_dim
        self.components = nn.ParameterList([
            nn.Parameter(
                torch.empty(m, h)
            )
            for m, h in zip(input_dim, kernel_size)
        ])
        self.kernel = nn.Parameter(torch.empty(*kernel_size))
        self.reset_parameters()

    def reset_parameters(self) -> None:

        for component in self.components:
            init.kaiming_uniform_(component, a=math.sqrt(5))

        init.kaiming_uniform_(self.kernel, a=math.sqrt(5))

    def forward(self, x):

        weights = self.get_weights()

        return x*weights

    def get_weights(self):

        out = self.kernel
        for i, component in enumerate(self.components):
            out = mode_n_product(out, component, i)

        return out

# %%
layer = LinearTucker((100, 100, 100), (10, 10, 10))

# %%
layer.components, layer.kernel.shape
# Out:
# (ParameterList(
#      (0): Parameter containing: [torch.float32 of size 100x10]
#      (1): Parameter containing: [torch.float32 of size 100x10]
#      (2): Parameter containing: [torch.float32 of size 100x10]
#  ),
#  torch.Size([10, 10, 10]))

# %%
layer.get_weights().shape
# Out:
# torch.Size([100, 100, 100])

# %%
X = torch.randn(100, 100, 100)
layer(X).shape
# Out:
# torch.Size([100, 100, 100])

# %%
from deepmeg.models import BaseModel

class TcModel(BaseModel):
    def __init__(
        self,
        input_size,
        kernel_size,
        maxpool_size,
        n_classes: int,
        dropout=None
    ):
        super().__init__()
        self.n_classes = n_classes
        self.tc = LinearTucker(input_size, kernel_size)
        self.dp = None if dropout is None else nn.Dropout(dropout)
        self.maxpool = nn.MaxPool3d((maxpool_size, maxpool_size, maxpool_size), maxpool_size) if maxpool_size else False
        if not maxpool_size:
            convargs = (input_size, (1, 1, 1), 0, 1)
        else:
            convargs = (input_size, (maxpool_size, maxpool_size, maxpool_size), 0, maxpool_size)
        self.maxpool_shape = compute_output_shape(*convargs)
        self.num_features = np.prod(self.maxpool_shape)
        self.linear = nn.Linear(self.num_features, self.n_classes)


    def forward(self, x: torch.Tensor):
        x = torch.unsqueeze(x, 1)

        x = self.tc(x)
        if self.dp:
            x = self.dp(x)
        if self.maxpool:
            x = self.maxpool(x)

        x = torch.flatten(x, start_dim=1)
        x = self.linear(x)

        return x

# %%
X = torch.randn(1, 100, 100, 100)

model = TcModel((100, 100, 100), (10, 10, 10), 10, 5)
model(X)
# Out:
# tensor([[ 0.0755,  0.0555, -0.0134,  0.0586, -0.0622]],
#        grad_fn=<AddmmBackward0>)

# %%
model.maxpool_shape, model.num_features
# Out:
# ((10, 10, 10), 1000)

# %% [markdown]
# ## Huxby decoding

# %%
from deepmeg.utils.colors import generate_cmap

cmap = generate_cmap(*[
    '#003535',
    '#00b2b2',
    '#b20000'
])
cmap

# %%
dataset = EpochsDataset.load('../data/huxby_3d_not_cropped_preprocessed.pt')
train, test = torch.utils.data.random_split(dataset, [.7, .3])

# %%
dataset = EpochsDataset.load('../data/huxby_whole_brain.pt')
train, test = torch.utils.data.random_split(dataset, [.7, .3])

# %%
fig = plot_2d_projections(next(iter(DataLoader(train)))[0][0].numpy(), cmap=cmap)

# %%
X, Y = next(iter(DataLoader(train, 10)))

# %%
X.shape[1:]
# Out:
# torch.Size([40, 64, 64])

# %%
from copy import deepcopy
from deepmeg.training.callbacks import Trainer, Callback


class PenalizedEarlyStopping(Callback):
    def __init__(self, patience=5, monitor='loss_train', measure='binary_accuracy_train', min_delta=0, restore_best_weights=True):
        super().__init__()
        self.patience = patience
        self.monitor = monitor
        self.measure = measure
        self.min_delta = min_delta
        self.restore_best_weights = restore_best_weights
        self.counter = 0
        self.min_criterion_value = np.inf
        self.max_measure_value = -np.inf
        self.best_weights = None

    def set_trainer(self, trainer: Trainer):
        super().set_trainer(trainer)
        self.model = self.trainer.model

    def on_epoch_end(self, epoch_num, metrics):
        criterion_value = metrics[self.monitor]
        measure_value = metrics[self.measure]
        if criterion_value < self.min_criterion_value or measure_value > self.max_measure_value:
            self.min_criterion_value = criterion_value
            self.counter = 0

            if measure_value > self.max_measure_value:
                self.best_weights = deepcopy(self.model.state_dict())
                self.max_measure_value = measure_value

        elif criterion_value > (self.min_criterion_value + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                if self.restore_best_weights:
                    self.restore()

                self.trainer.interrupt()

    def restore(self):
        self.model.load_state_dict(self.best_weights)

# %%
model = TcModel(
    X.shape[1:],
    (10, 10, 10),
    False,
    Y.shape[1],
    .4
)

optimizer = torch.optim.Adam#W(model.parameters(), lr=1e-3)
loss = torch.nn.BCEWithLogitsLoss()
metric = accuracy

model.compile(
    optimizer,
    loss,
    metric,
    callbacks=[
        PrintingCallback(),
        L2Reg(
            [
                'tc.kernel', *[f'tc.components.{i}' for i in range(3)]
            ],
            0.01
        ),
        PenalizedEarlyStopping(monitor='loss_val', measure='accuracy_val', restore_best_weights=True, patience=25)
    ]
)

# %%
model.maxpool_shape, model.num_features
# Out:
# ((40, 64, 64), 163840)

# %%
if hasattr(sys.stdout, 'file'):
    sys.stdout = sys.stdout.file

# %%
history = model.fit(train, n_epochs=150, batch_size=200, val_batch_size=60)
plot_metrics(history)
# Out:
# Epoch 0:  loss_train:  0.8375   |    accuracy_train:  0.2314   |    loss_val:  0.8410   |    accuracy_val:  0.2889
# Epoch 1:  loss_train:  0.8118   |    accuracy_train:  0.4549   |    loss_val:  0.8429   |    accuracy_val:  0.4019
# Epoch 2:  loss_train:  0.7939   |    accuracy_train:  0.5631   |    loss_val:  0.8430   |    accuracy_val:  0.4755
# Epoch 3:  loss_train:  0.7766   |    accuracy_train:  0.6466   |    loss_val:  0.8408   |    accuracy_val:  0.5319
# Epoch 4:  loss_train:  0.7601   |    accuracy_train:  0.7179   |    loss_val:  0.8405   |    accuracy_val:  0.5875
# Epoch 5:  loss_train:  0.7438   |    accuracy_train:  0.7779   |    loss_val:  0.8442   |    accuracy_val:  0.5917
# Epoch 6:  loss_train:  0.7283   |    accuracy_train:  0.8411   |    loss_val:  0.8508   |    accuracy_val:  0.6273
# Epoch 7:  loss_train:  0.7105   |    accuracy_train:  0.8740   |    loss_val:  0.8596   |    accuracy_val:  0.6481
# Epoch 8:  loss_train:  0.6938   |    accuracy_train:  0.8944   |    loss_val:  0.8699   |    accuracy_val:  0.6606
# Epoch 9:  loss_train:  0.6776   |    accuracy_train:  0.9021   |    loss_val:  0.8839   |    accuracy_val:  0.6648
# Epoch 10: loss_train:  0.6571   |    accuracy_train:  0.9326   |    loss_val:  0.9026   |    accuracy_val:  0.7079
# Epoch 11: loss_train:  0.6414   |    accuracy_train:  0.9351   |    loss_val:  0.9236   |    accuracy_val:  0.7463
# Epoch 12: loss_train:  0.6190   |    accuracy_train:  0.9543   |    loss_val:  0.9499   |    accuracy_val:  0.7593
# Epoch 13: loss_train:  0.6014   |    accuracy_train:  0.9649   |    loss_val:  0.9751   |    accuracy_val:  0.7759
# Epoch 14: loss_train:  0.5760   |    accuracy_train:  0.9709   |    loss_val:  1.0124   |    accuracy_val:  0.7972
# Epoch 15: loss_train:  0.5530   |    accuracy_train:  0.9745   |    loss_val:  1.0591   |    accuracy_val:  0.7801
# Epoch 16: loss_train:  0.5284   |    accuracy_train:  0.9773   |    loss_val:  1.1112   |    accuracy_val:  0.7843
# Epoch 17: loss_train:  0.5035   |    accuracy_train:  0.9849   |    loss_val:  1.1829   |    accuracy_val:  0.7806
# Epoch 18: loss_train:  0.4828   |    accuracy_train:  0.9963   |    loss_val:  1.2453   |    accuracy_val:  0.7847
# Epoch 19: loss_train:  0.4557   |    accuracy_train:  0.9938   |    loss_val:  1.3315   |    accuracy_val:  0.7889
# Epoch 20: loss_train:  0.4368   |    accuracy_train:  0.9913   |    loss_val:  1.4381   |    accuracy_val:  0.7852
# Epoch 21: loss_train:  0.4095   |    accuracy_train:  0.9988   |    loss_val:  1.5433   |    accuracy_val:  0.7810
# Epoch 22: loss_train:  0.3948   |    accuracy_train:  0.9963   |    loss_val:  1.6632   |    accuracy_val:  0.7898
# Epoch 23: loss_train:  0.3805   |    accuracy_train:  0.9974   |    loss_val:  1.7755   |    accuracy_val:  0.7852
# Epoch 24: loss_train:  0.3616   |    accuracy_train:  1.0000   |    loss_val:  1.8813   |    accuracy_val:  0.7676
# Epoch 25: loss_train:  0.3489   |    accuracy_train:  1.0000   |    loss_val:  2.0099   |    accuracy_val:  0.7894
# Epoch 26: loss_train:  0.3426   |    accuracy_train:  1.0000   |    loss_val:  2.1965   |    accuracy_val:  0.7764
# Epoch 27: loss_train:  0.3433   |    accuracy_train:  1.0000   |    loss_val:  2.3556   |    accuracy_val:  0.7810
# Epoch 28: loss_train:  0.3436   |    accuracy_train:  1.0000   |    loss_val:  2.4031   |    accuracy_val:  0.7847
# Epoch 29: loss_train:  0.3237   |    accuracy_train:  1.0000   |    loss_val:  2.5017   |    accuracy_val:  0.7722
# Epoch 30: loss_train:  0.3238   |    accuracy_train:  0.9988   |    loss_val:  2.6218   |    accuracy_val:  0.7810
# Epoch 31: loss_train:  0.3043   |    accuracy_train:  1.0000   |    loss_val:  2.7266   |    accuracy_val:  0.7852
# Epoch 32: loss_train:  0.3070   |    accuracy_train:  1.0000   |    loss_val:  2.7694   |    accuracy_val:  0.7769
# Epoch 33: loss_train:  0.3033   |    accuracy_train:  1.0000   |    loss_val:  2.9200   |    accuracy_val:  0.7681
# Epoch 34: loss_train:  0.3001   |    accuracy_train:  1.0000   |    loss_val:  3.0041   |    accuracy_val:  0.7852
# Epoch 35: loss_train:  0.2962   |    accuracy_train:  1.0000   |    loss_val:  3.0056   |    accuracy_val:  0.7810
# Epoch 36: loss_train:  0.3030   |    accuracy_train:  1.0000   |    loss_val:  3.2450   |    accuracy_val:  0.7764
# Epoch 37: loss_train:  0.2986   |    accuracy_train:  1.0000   |    loss_val:  3.2240   |    accuracy_val:  0.7722
# Epoch 38: loss_train:  0.3005   |    accuracy_train:  1.0000   |    loss_val:  3.4482   |    accuracy_val:  0.7977
# Epoch 39: loss_train:  0.3028   |    accuracy_train:  1.0000   |    loss_val:  3.4623   |    accuracy_val:  0.7903
# Epoch 40: loss_train:  0.3020   |    accuracy_train:  1.0000   |    loss_val:  3.6111   |    accuracy_val:  0.7634
# Epoch 41: loss_train:  0.3109   |    accuracy_train:  0.9975   |    loss_val:  3.5206   |    accuracy_val:  0.7509
# Epoch 42: loss_train:  0.2959   |    accuracy_train:  1.0000   |    loss_val:  3.7023   |    accuracy_val:  0.7810
# Epoch 43: loss_train:  0.2916   |    accuracy_train:  1.0000   |    loss_val:  3.5919   |    accuracy_val:  0.7810
# Epoch 44: loss_train:  0.2912   |    accuracy_train:  1.0000   |    loss_val:  3.7305   |    accuracy_val:  0.7894
# Epoch 45: loss_train:  0.2914   |    accuracy_train:  1.0000   |    loss_val:  3.8330   |    accuracy_val:  0.7389
# Epoch 46: loss_train:  0.2920   |    accuracy_train:  1.0000   |    loss_val:  3.8093   |    accuracy_val:  0.7519
# Epoch 47: loss_train:  0.2887   |    accuracy_train:  1.0000   |    loss_val:  3.7701   |    accuracy_val:  0.7417
# Epoch 48: loss_train:  0.2986   |    accuracy_train:  1.0000   |    loss_val:  4.0461   |    accuracy_val:  0.7639
# Epoch 49: loss_train:  0.2983   |    accuracy_train:  1.0000   |    loss_val:  3.8723   |    accuracy_val:  0.7602
# Epoch 50: loss_train:  0.2912   |    accuracy_train:  1.0000   |    loss_val:  4.1138   |    accuracy_val:  0.7727
# Epoch 51: loss_train:  0.2962   |    accuracy_train:  1.0000   |    loss_val:  4.0264   |    accuracy_val:  0.7681
# Epoch 52: loss_train:  0.2861   |    accuracy_train:  1.0000   |    loss_val:  4.0910   |    accuracy_val:  0.7722
# Epoch 53: loss_train:  0.2946   |    accuracy_train:  1.0000   |    loss_val:  4.1264   |    accuracy_val:  0.7722
#  36%|███▌      | 54/150 [03:11<05:41,  3.55s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[230], line 1
# ----> 1 history = model.fit(train, n_epochs=150, batch_size=200, val_batch_size=60)
#       2 plot_metrics(history)
#
# File ~/Projects/deepmeg/deepmeg/models/__init__.py:223, in BaseModel.fit(self, data, n_epochs, batch_size, val_data, val_batch_size, update_every_n_batches, eval_on_n_batches, eval_every_n_epochs)
#     199 """Trains the model on the given data.
#     200
#     201 Args:
#    (...)
#     220 array([0, 1, 1, ..., 1, 0, 1])
#     221 """
#     222 train_loader, val_loader = self._prepare_dataloaders(data, batch_size, val_data, val_batch_size)
# --> 223 return self.trainer.fit(train_loader, n_epochs, val_loader, update_every_n_batches, eval_on_n_batches, eval_every_n_epochs)
#
# File ~/Projects/deepmeg/deepmeg/training/trainers.py:352, in Trainer.fit(self, train_loader, num_epochs, val_loader, update_every_n_batches, eval_on_n_batches, eval_every_n_epochs)
#     349     for callback in self.callbacks:
#     350         callback.on_epoch_begin(i)
# --> 352 train_metrics = self.fit_epoch(train_loader, update_every_n_batches)
#     354 train_metrics = {f'{key}_train': value for key, value in train_metrics.items()}
#     355 val_metrics = False
#
# File ~/Projects/deepmeg/deepmeg/training/trainers.py:289, in Trainer.fit_epoch(self, train_loader, update_every_n_batches)
#     286 train_iterator = iter(train_loader)
#     288 while True:
# --> 289     batch_metrics = self.fit_batch(train_iterator, update_every_n_batches)
#     291     if batch_metrics is None or self._interrupt:
#     292         break
#
# File ~/Projects/deepmeg/deepmeg/training/trainers.py:237, in Trainer.fit_batch(self, train_iterator, update_every_n_batches)
#     234     else:
#     235         break
# --> 237 ys_pred = self.model.train()(xs)
#     238 loss = self.criterion(ys_pred, ys_true)
#     240 if self.callbacks:
#
# File ~/Projects/deepmeg/venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[158], line 31, in TcModel.forward(self, x)
#      29 x = self.tc(x)
#      30 if self.dp:
# ---> 31     x = self.dp(x)
#      32 if self.maxpool:
#      33     x = self.maxpool(x)
#
# File ~/Projects/deepmeg/venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Projects/deepmeg/venv/lib/python3.11/site-packages/torch/nn/modules/dropout.py:59, in Dropout.forward(self, input)
#      58 def forward(self, input: Tensor) -> Tensor:
# ---> 59     return F.dropout(input, self.p, self.training, self.inplace)
#
# File ~/Projects/deepmeg/venv/lib/python3.11/site-packages/torch/nn/functional.py:1252, in dropout(input, p, training, inplace)
#    1250 if p < 0.0 or p > 1.0:
#    1251     raise ValueError("dropout probability has to be between 0 and 1, " "but got {}".format(p))
# -> 1252 return _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#
# KeyboardInterrupt:

# %%
train_result = model.evaluate(train)
result = model.evaluate(test)

for measure, value in train_result.items():
    print(f'train_{measure}: {value}')

for measure, value in result.items():
    print(f'{measure}: {value}')
# Out:
# train_loss: 1.2827597910707647
# train_accuracy: 0.9227208603512157
# loss: 3.704850500280207
# accuracy: 0.8190274780446832

# %%
plot_2d_projections(model.tc.get_weights().detach().numpy(), cmap=cmap)
